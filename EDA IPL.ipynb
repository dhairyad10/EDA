# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("matches.csv")
df = data.copy()

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data.shape
# Out:
# (756, 18)

# %%
df.head(20)
# Out:
#     id    Season       city        date                        team1  \
# 0    1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1    2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2    3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3    4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4    5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5    6  IPL-2017  Hyderabad  09-04-2017                Gujarat Lions
# 6    7  IPL-2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7    8  IPL-2017     Indore  10-04-2017  Royal Challengers Bangalore
# 8    9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 9   10  IPL-2017     Mumbai  12-04-2017          Sunrisers Hyderabad
# 10  11  IPL-2017    Kolkata  13-04-2017              Kings XI Punjab
# 11  12  IPL-2017  Bangalore  14-04-2017  Royal Challengers Bangalore
# 12  13  IPL-2017     Rajkot  14-04-2017       Rising Pune Supergiant
# ...

# %%
print(df.isnull().sum())
df.isnull().any()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64
# id                 False
# Season             False
# city                True
# date               False
# team1              False
# team2              False
# toss_winner        False
# toss_decision      False
# result             False
# dl_applied         False
# winner              True
# win_by_runs        False
# win_by_wickets     False
# player_of_match     True
# venue              False
# umpire1             True
# umpire2             True
# umpire3             True
# dtype: bool

# %%
df.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %%
df['id'].count()
# Out:
# 756

# %%
df['Season'].unique()
# Out:
# array(['IPL-2017', 'IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011',
#        'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016',
#        'IPL-2018', 'IPL-2019'], dtype=object)

# %%
df[df.win_by_runs == df.win_by_runs.max()]
df.iloc[data['win_by_runs'].idxmax()]
# Out:
# id                               44
# Season                     IPL-2017
# city                          Delhi
# date                     06-05-2017
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
df['win_by_runs'].idxmax()
# Out:
# 43

# %%
df.iloc[43]
# Out:
# id                               44
# Season                     IPL-2017
# city                          Delhi
# date                     06-05-2017
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
df.iloc[df['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# Season                                           IPL-2017
# city                                               Rajkot
# date                                           07-04-2017
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
df[df.win_by_wickets == 0]
# Out:
#         id    Season       city        date                        team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8        9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 13      14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14      15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
# ..     ...       ...        ...         ...                          ...
# 743  11339  IPL-2019  Hyderabad  29-04-2019          Sunrisers Hyderabad
# 744  11340  IPL-2019  Bengaluru  30-04-2019  Royal Challengers Bangalore
# 745  11341  IPL-2019    Chennai  01-05-2019          Chennai Super Kings
# 746  11342  IPL-2019     Mumbai  02-05-2019               Mumbai Indians
# 755  11415  IPL-2019  Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
fig_dims = (20,4)
fig, ax = plt.subplots(figsize = fig_dims)
sns.countplot(x = 'Season', ax = ax, data = df)
plt.show()

# %%
fig_dims = (15,4)
fig, ax = plt.subplots(figsize = fig_dims)
sns.countplot(x = 'Season', data = df)
# Out:
# <AxesSubplot:xlabel='Season', ylabel='count'>

# %%
d = df.winner.value_counts()
sns.barplot(x = d, y = d.index)
# Out:
# <AxesSubplot:xlabel='winner'>

# %%
mom = df.player_of_match.value_counts()
mom.max()
mom[mom == 21]
# Out:
# CH Gayle    21
# Name: player_of_match, dtype: int64

# %%
data['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
df[(df.umpire1 == 'Nitin Menon') | (df.umpire2 == 'Nitin Menon') | (df.umpire3 == 'Nitin Menon')].count()
# Out:
# id                 52
# Season             52
# city               52
# date               52
# team1              52
# team2              52
# toss_winner        52
# toss_decision      52
# result             52
# dl_applied         52
# winner             52
# win_by_runs        52
# win_by_wickets     52
# player_of_match    52
# venue              52
# umpire1            52
# umpire2            52
# umpire3            33
# dtype: int64

# %%
df[df.win_by_runs > 0].count()
# Out:
# id                 337
# Season             337
# city               334
# date               337
# team1              337
# team2              337
# toss_winner        337
# toss_decision      337
# result             337
# dl_applied         337
# winner             337
# win_by_runs        337
# win_by_wickets     337
# player_of_match    337
# venue              337
# umpire1            336
# umpire2            336
# umpire3             50
# dtype: int64

# %%
df[df.win_by_runs == 0].count()
# Out:
# id                 419
# Season             419
# city               415
# date               419
# team1              419
# team2              419
# toss_winner        419
# toss_decision      419
# result             419
# dl_applied         419
# winner             415
# win_by_runs        419
# win_by_wickets     419
# player_of_match    415
# venue              419
# umpire1            418
# umpire2            418
# umpire3             69
# dtype: int64

# %%
tosswin_matchwin = df[df.toss_winner == df.winner].id.count()
tosswin_matchlose = df[df.toss_winner != df.winner].id.count()
print(tosswin_matchwin, tosswin_matchlose )
# Out:
# 393 363

# %%
df.loc[df.win_by_runs == df.win_by_runs.max()].values[0]
# Out:
# array([44, 'IPL-2017', 'Delhi', '06-05-2017', 'Mumbai Indians',
#        'Delhi Daredevils', 'Delhi Daredevils', 'field', 'normal', 0,
#        'Mumbai Indians', 146, 0, 'LMP Simmons', 'Feroz Shah Kotla',
#        'Nitin Menon', 'CK Nandan', nan], dtype=object)

# %%
tie = (df.result == 'tie')
print(tie.sum())
df[tie]
# Out:
# 9
#         id    Season       city        date                        team1  \
# 33      34  IPL-2017     Rajkot  29-04-2017                Gujarat Lions
# 125    126  IPL-2009  Cape Town  23-04-2009             Rajasthan Royals
# 189    190  IPL-2010    Chennai  21-03-2010              Kings XI Punjab
# 387    388  IPL-2013  Hyderabad  07-04-2013  Royal Challengers Bangalore
# 400    401  IPL-2013  Bangalore  16-04-2013             Delhi Daredevils
# 475    476  IPL-2014  Abu Dhabi  29-04-2014             Rajasthan Royals
# 535    536  IPL-2015  Ahmedabad  21-04-2015             Rajasthan Royals
# 705  11146  IPL-2019      Delhi  30-03-2019        Kolkata Knight Riders
# 746  11342  IPL-2019     Mumbai  02-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 33                Mumbai Indians                Gujarat Lions           bat
# 125        Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
df[tie]
# Out:
#         id    Season       city        date                        team1  \
# 33      34  IPL-2017     Rajkot  29-04-2017                Gujarat Lions
# 125    126  IPL-2009  Cape Town  23-04-2009             Rajasthan Royals
# 189    190  IPL-2010    Chennai  21-03-2010              Kings XI Punjab
# 387    388  IPL-2013  Hyderabad  07-04-2013  Royal Challengers Bangalore
# 400    401  IPL-2013  Bangalore  16-04-2013             Delhi Daredevils
# 475    476  IPL-2014  Abu Dhabi  29-04-2014             Rajasthan Royals
# 535    536  IPL-2015  Ahmedabad  21-04-2015             Rajasthan Royals
# 705  11146  IPL-2019      Delhi  30-03-2019        Kolkata Knight Riders
# 746  11342  IPL-2019     Mumbai  02-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 33                Mumbai Indians                Gujarat Lions           bat
# 125        Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
a = df[df.win_by_runs >= 50].winner
a.value_counts()
# Out:
# Chennai Super Kings            13
# Mumbai Indians                 10
# Royal Challengers Bangalore     7
# Rajasthan Royals                6
# Kings XI Punjab                 5
# Delhi Daredevils                4
# Kolkata Knight Riders           3
# Deccan Chargers                 3
# Sunrisers Hyderabad             2
# Rising Pune Supergiant          1
# Name: winner, dtype: int64

# %%
nitin = df[(df.umpire1 == "Nitin Menon") | (df.umpire2 == "Nitin Menon")]
nitin.id.count()  # count the ids off match where nitin menon was fiels umpire
# Out:
# 42

# %%
df[df.win_by_wickets == 10].winner.value_counts()
# Out:
# Royal Challengers Bangalore    3
# Kolkata Knight Riders          1
# Kings XI Punjab                1
# Deccan Chargers                1
# Delhi Daredevils               1
# Rajasthan Royals               1
# Mumbai Indians                 1
# Chennai Super Kings            1
# Sunrisers Hyderabad            1
# Name: winner, dtype: int64

# %%
#instances when RCB wo by 10 wickets
df[(df.win_by_wickets == 10) & (df.winner == 'Royal Challengers Bangalore')]
# Out:
#        id    Season       city        date             team1  \
# 183   184  IPL-2010  Bangalore  18-03-2010  Rajasthan Royals
# 542   543  IPL-2015      Delhi  26-04-2015  Delhi Daredevils
# 683  7941  IPL-2018     Indore  14-05-2018   Kings XI Punjab
#
#                            team2                  toss_winner toss_decision  \
# 183  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 542  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 683  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#      result  dl_applied                       winner  win_by_runs  \
# 183  normal           0  Royal Challengers Bangalore            0
# 542  normal           0  Royal Challengers Bangalore            0
# 683  normal           0  Royal Challengers Bangalore            0
#
#      win_by_wickets player_of_match                   venue         umpire1  \
# ...

# %%
seasons = df.groupby('Season')
for Season,Season_df  in seasons:
    print(Season)
    print(Season_df)
# Out:
# IPL-2008
#       id    Season        city        date                        team1  \
# 59    60  IPL-2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 60    61  IPL-2008  Chandigarh  19-04-2008          Chennai Super Kings
# 61    62  IPL-2008       Delhi  19-04-2008             Rajasthan Royals
# 62    63  IPL-2008      Mumbai  20-04-2008               Mumbai Indians
# 63    64  IPL-2008     Kolkata  20-04-2008              Deccan Chargers
# 64    65  IPL-2008      Jaipur  21-04-2008              Kings XI Punjab
# 65    66  IPL-2008   Hyderabad  22-04-2008              Deccan Chargers
# 66    67  IPL-2008     Chennai  23-04-2008          Chennai Super Kings
# 67    68  IPL-2008   Hyderabad  24-04-2008              Deccan Chargers
# 68    69  IPL-2008  Chandigarh  25-04-2008              Kings XI Punjab
# 69    70  IPL-2008   Bangalore  26-04-2008  Royal Challengers Bangalore
# 70    71  IPL-2008     Chennai  26-04-2008        Kolkata Knight Riders
# ...

# %%
seasons.get_group('IPL-2018')
# Out:
#        id    Season       city        date                        team1  \
# 636  7894  IPL-2018     Mumbai  07-04-2018               Mumbai Indians
# 637  7895  IPL-2018     Mohali  08-04-2018             Delhi Daredevils
# 638  7896  IPL-2018    Kolkata  08-04-2018  Royal Challengers Bangalore
# 639  7897  IPL-2018  Hyderabad  09-04-2018             Rajasthan Royals
# 640  7898  IPL-2018    Chennai  10-04-2018        Kolkata Knight Riders
# 641  7899  IPL-2018     Jaipur  11-04-2018             Rajasthan Royals
# 642  7900  IPL-2018  Hyderabad  12-04-2018               Mumbai Indians
# 643  7901  IPL-2018  Bengaluru  13-04-2018              Kings XI Punjab
# 644  7902  IPL-2018     Mumbai  14-04-2018               Mumbai Indians
# 645  7903  IPL-2018    Kolkata  14-04-2018        Kolkata Knight Riders
# 646  7904  IPL-2018  Bengaluru  15-04-2018             Rajasthan Royals
# 647  7905  IPL-2018     Mohali  15-04-2018              Kings XI Punjab
# ...

# %%
seasons['winner'].value_counts()
# Out:
# Season    winner
# IPL-2008  Rajasthan Royals               13
#           Kings XI Punjab                10
#           Chennai Super Kings             9
#           Delhi Daredevils                7
#           Mumbai Indians                  7
#                                          ..
# IPL-2019  Kings XI Punjab                 6
#           Kolkata Knight Riders           6
#           Sunrisers Hyderabad             6
#           Rajasthan Royals                5
#           Royal Challengers Bangalore     5
# Name: winner, Length: 100, dtype: int64

# %%
by_runs = df.sort_values(by = 'win_by_runs', ascending = False)
by_runs['winner']
by_runs[['winner', 'win_by_runs']].iloc[0:10]
# Out:
#                           winner  win_by_runs
# 43                Mumbai Indians          146
# 619  Royal Challengers Bangalore          144
# 59         Kolkata Knight Riders          140
# 556  Royal Challengers Bangalore          138
# 410  Royal Challengers Bangalore          130
# 706          Sunrisers Hyderabad          118
# 295              Kings XI Punjab          111
# 114             Rajasthan Royals          105
# 676               Mumbai Indians          102
# 182               Mumbai Indians           98

# %%
df[df.win_by_runs >= 100]['winner'].value_counts()
# Out:
# Royal Challengers Bangalore    3
# Mumbai Indians                 2
# Kolkata Knight Riders          1
# Rajasthan Royals               1
# Kings XI Punjab                1
# Sunrisers Hyderabad            1
# Name: winner, dtype: int64
